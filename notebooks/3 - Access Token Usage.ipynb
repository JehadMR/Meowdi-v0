# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\jehad\.virtualenvs\meowdi-v0-b0bmwkgo\lib\site-packages (2.28.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jehad\.virtualenvs\meowdi-v0-b0bmwkgo\lib\site-packages (from requests) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jehad\.virtualenvs\meowdi-v0-b0bmwkgo\lib\site-packages (from requests) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jehad\.virtualenvs\meowdi-v0-b0bmwkgo\lib\site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jehad\.virtualenvs\meowdi-v0-b0bmwkgo\lib\site-packages (from requests) (3.3)

# %%
import requests 
import datetime
from urllib.parse import urlencode

# %%
import base64

# %%
client_id = '8b71e3cc473d48379da0ff1bcee2fcdc'
client_secret = '038a7a28a772437ba70aceb8b7123cef'

# %%
class SpotifyAPI (object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self): 
        """
        Returns a base64 encoded string - NOT BYTES
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    
    def get_token_headers(self):
        
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}" #<base64 encoded client_id:client_secret>
            , "Content-Type": "application/x-www-form-urlencoded"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        }
        

            
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
             return False
        else:
            data = r.json()
            now = datetime.datetime.now()
            access_token = data['access_token']
            expires_in = data['expires_in'] #in seconds
            expires = now + datetime.timedelta(seconds=expires_in)
            self.access_token = access_token
            self.access_token_expires = expires
            self.access_token_did_expire = expires < now
            return True

# %%
client = SpotifyAPI(client_id, client_secret)

# %%
client.perform_auth()
# Out:
# True

# %%
access_token = client.access_token
print(access_token)
# Out:
# BQD44yJNnQXM3c9IIFVwpgkUaSyMh6DrDpCoWV2qe_rS4TNwEVxf1HyazbNxbr41oh95WVdk3KiMNcJ9fSwV72AxZP8lxoG7FiHrBRgwA5q_FTIkPxD_

# %%
# Client --Spotify Here-- Search 
headers = {
    "Authorization": f"Bearer {access_token}"
}
endpoint = "https://api.spotify.com/v1/search"
data = urlencode({"q": "Starships Nikki Minaj", "type": "track"})

lookup_url = f"{endpoint}?{data}"
r = requests.get(lookup_url, headers=headers)
print(lookup_url)
print(r.status_code)
# Out:
# https://api.spotify.com/v1/search?q=Starships+Nikki+Minaj&type=track
# 200

# %%
r.json()
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Starships+Nikki+Minaj&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6OfCOPtcPuhlAovGJ52uZO'},
#      'href': 'https://api.spotify.com/v1/albums/6OfCOPtcPuhlAovGJ52uZO',
#      'id': '6OfCOPtcPuhlAovGJ52uZO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27385235715597dcd07bb9e0f84',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0285235715597dcd07bb9e0f84',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485185235715597dcd07bb9e0f84',
#        'width': 64}],
#      'name': 'Pink Friday ... Roman Reloaded',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:6OfCOPtcPuhlAovGJ52uZO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 210626,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51200060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1oHNvJVbFkexQc0BpQp7Y4'},
#     'href': 'https://api.spotify.com/v1/tracks/1oHNvJVbFkexQc0BpQp7Y4',
#     'id': '1oHNvJVbFkexQc0BpQp7Y4',
#     'is_local': False,
#     'name': 'Starships',
#     'popularity': 74,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:1oHNvJVbFkexQc0BpQp7Y4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6fABwONLawdFjkDpLx41j8'},
#      'href': 'https://api.spotify.com/v1/albums/6fABwONLawdFjkDpLx41j8',
#      'id': '6fABwONLawdFjkDpLx41j8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734f0aae4e435a794e0e24d115',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024f0aae4e435a794e0e24d115',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514f0aae4e435a794e0e24d115',
#        'width': 64}],
#      'name': 'Pink Friday ... Roman Reloaded (Deluxe)',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:6fABwONLawdFjkDpLx41j8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 210626,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51200060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/59RSrxkSKSixEWBAIvE5Wa'},
#     'href': 'https://api.spotify.com/v1/tracks/59RSrxkSKSixEWBAIvE5Wa',
#     'id': '59RSrxkSKSixEWBAIvE5Wa',
#     'is_local': False,
#     'name': 'Starships',
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:59RSrxkSKSixEWBAIvE5Wa'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/11WBJUabzUXj583BoGUYMD'},
#      'href': 'https://api.spotify.com/v1/albums/11WBJUabzUXj583BoGUYMD',
#      'id': '11WBJUabzUXj583BoGUYMD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f5314afc14d868523edfaf3d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f5314afc14d868523edfaf3d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f5314afc14d868523edfaf3d',
#        'width': 64}],
#      'name': 'Pink Friday ... Roman Reloaded',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:11WBJUabzUXj583BoGUYMD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 210613,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCM51200335'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0dvYprV2t3UA0MDc4nUuAY'},
#     'href': 'https://api.spotify.com/v1/tracks/0dvYprV2t3UA0MDc4nUuAY',
#     'id': '0dvYprV2t3UA0MDc4nUuAY',
#     'is_local': False,
#     'name': 'Starships - Edit',
#     'popularity': 45,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:0dvYprV2t3UA0MDc4nUuAY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2D2rriWruRrRFq2AAholPp'},
#      'href': 'https://api.spotify.com/v1/albums/2D2rriWruRrRFq2AAholPp',
#      'id': '2D2rriWruRrRFq2AAholPp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bd6eee29c9fb9f9bfdb588ee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bd6eee29c9fb9f9bfdb588ee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bd6eee29c9fb9f9bfdb588ee',
#        'width': 64}],
#      'name': 'Pink Friday ... Roman Reloaded (Deluxe Edition)',
#      'release_date': '2012-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:2D2rriWruRrRFq2AAholPp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 210613,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51200060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1UgW0l9aia2l4SjQSGwF2q'},
#     'href': 'https://api.spotify.com/v1/tracks/1UgW0l9aia2l4SjQSGwF2q',
#     'id': '1UgW0l9aia2l4SjQSGwF2q',
#     'is_local': False,
#     'name': 'Starships',
#     'popularity': 50,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:1UgW0l9aia2l4SjQSGwF2q'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3zzfHV7JM2FAqoRq0rZqwI'},
#      'href': 'https://api.spotify.com/v1/albums/3zzfHV7JM2FAqoRq0rZqwI',
#      'id': '3zzfHV7JM2FAqoRq0rZqwI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27344b99faf8064d30c663024ab',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0244b99faf8064d30c663024ab',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485144b99faf8064d30c663024ab',
#        'width': 64}],
#      'name': 'Pink Friday: Roman Reloaded The Re-Up',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:3zzfHV7JM2FAqoRq0rZqwI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 2,
#     'duration_ms': 210613,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCM51200335'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2qblnYRaKJO8K5dx39bP68'},
#     'href': 'https://api.spotify.com/v1/tracks/2qblnYRaKJO8K5dx39bP68',
#     'id': '2qblnYRaKJO8K5dx39bP68',
#     'is_local': False,
#     'name': 'Starships - Edit',
#     'popularity': 40,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:2qblnYRaKJO8K5dx39bP68'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['CA', 'JP', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/78XjkzI0J1YpzKUPgzWbat'},
#      'href': 'https://api.spotify.com/v1/albums/78XjkzI0J1YpzKUPgzWbat',
#      'id': '78XjkzI0J1YpzKUPgzWbat',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fa2a62fe48c2c929c834c084',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fa2a62fe48c2c929c834c084',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fa2a62fe48c2c929c834c084',
#        'width': 64}],
#      'name': 'Pink Friday: Roman Reloaded The Re-Up',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:78XjkzI0J1YpzKUPgzWbat'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['CA', 'JP', 'MX', 'US'],
#     'disc_number': 2,
#     'duration_ms': 210626,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51200060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4AiGz7pTyLXBHjniRuioaw'},
#     'href': 'https://api.spotify.com/v1/tracks/4AiGz7pTyLXBHjniRuioaw',
#     'id': '4AiGz7pTyLXBHjniRuioaw',
#     'is_local': False,
#     'name': 'Starships',
#     'popularity': 50,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4AiGz7pTyLXBHjniRuioaw'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3C81mDhWllB5q56pfvik3U'},
#      'href': 'https://api.spotify.com/v1/albums/3C81mDhWllB5q56pfvik3U',
#      'id': '3C81mDhWllB5q56pfvik3U',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730841a28ca69a34d2a45e58ed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020841a28ca69a34d2a45e58ed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510841a28ca69a34d2a45e58ed',
#        'width': 64}],
#      'name': 'Ultimate Pitch Perfect (Original Motion Picture Soundtrack)',
#      'release_date': '2015-02-10',
#      'release_date_precision': 'day',
#      'total_tracks': 24,
#      'type': 'album',
#      'uri': 'spotify:album:3C81mDhWllB5q56pfvik3U'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 212133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCM51200059'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1M7Wk9JzSCkK20BLr5drGF'},
#     'href': 'https://api.spotify.com/v1/tracks/1M7Wk9JzSCkK20BLr5drGF',
#     'id': '1M7Wk9JzSCkK20BLr5drGF',
#     'is_local': False,
#     'name': 'Starships',
#     'popularity': 31,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:1M7Wk9JzSCkK20BLr5drGF'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BB',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BW',
#       'BY',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'GA',
#       'GB',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KM',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LI',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SN',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TR',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UZ',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5yZTwH7fBz5vKCuvAOUFih'},
#      'href': 'https://api.spotify.com/v1/albums/5yZTwH7fBz5vKCuvAOUFih',
#      'id': '5yZTwH7fBz5vKCuvAOUFih',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a36966206a40cee6e2aaf843',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a36966206a40cee6e2aaf843',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a36966206a40cee6e2aaf843',
#        'width': 64}],
#      'name': 'Pink Friday ... Roman Reloaded (Deluxe)',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:5yZTwH7fBz5vKCuvAOUFih'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BB',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BW',
#      'BY',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'GA',
#      'GB',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KM',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LI',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TR',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UZ',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 210626,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCM51200335'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7rEypsXZlHM0fCY2yynd7J'},
#     'href': 'https://api.spotify.com/v1/tracks/7rEypsXZlHM0fCY2yynd7J',
#     'id': '7rEypsXZlHM0fCY2yynd7J',
#     'is_local': False,
#     'name': 'Starships - Edit',
#     'popularity': 42,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7rEypsXZlHM0fCY2yynd7J'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1XLirBHtfQoJgCrTodBZCj'},
#      'href': 'https://api.spotify.com/v1/albums/1XLirBHtfQoJgCrTodBZCj',
#      'id': '1XLirBHtfQoJgCrTodBZCj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ae77498df9fdfabaeb7dd495',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ae77498df9fdfabaeb7dd495',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ae77498df9fdfabaeb7dd495',
#        'width': 64}],
#      'name': 'Pink Friday ... Roman Reloaded (Deluxe)',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:1XLirBHtfQoJgCrTodBZCj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 210626,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51200060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3QhJh0PtPq0J0yjfkNyzKq'},
#     'href': 'https://api.spotify.com/v1/tracks/3QhJh0PtPq0J0yjfkNyzKq',
#     'id': '3QhJh0PtPq0J0yjfkNyzKq',
#     'is_local': False,
#     'name': 'Starships',
#     'popularity': 24,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3QhJh0PtPq0J0yjfkNyzKq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/07aahkgYoHTTTV0RYKkMip'},
#      'href': 'https://api.spotify.com/v1/albums/07aahkgYoHTTTV0RYKkMip',
#      'id': '07aahkgYoHTTTV0RYKkMip',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730cae75732f70bb3ec7478c8f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020cae75732f70bb3ec7478c8f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510cae75732f70bb3ec7478c8f',
#        'width': 64}],
#      'name': 'Pink Friday ... Roman Reloaded (Deluxe Edition)',
#      'release_date': '2012-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:07aahkgYoHTTTV0RYKkMip'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 210626,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCM51200335'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4WDCh3QFVWHUsSKjqbUwdA'},
#     'href': 'https://api.spotify.com/v1/tracks/4WDCh3QFVWHUsSKjqbUwdA',
#     'id': '4WDCh3QFVWHUsSKjqbUwdA',
#     'is_local': False,
#     'name': 'Starships - Edit',
#     'popularity': 30,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4WDCh3QFVWHUsSKjqbUwdA'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 10}}
